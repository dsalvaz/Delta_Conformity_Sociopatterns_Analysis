# %%
from formatting_hospital_file import read_hospital_file
from delta_conformity_hospital_run_and_viz import run_delta_conformity, read_and_plot_results

# %%
file_list = [
    "hospital_ward/mond.txt",
    "hospital_ward/tues.txt",
    "hospital_ward/wed.txt",
    "hospital_ward/thur.txt",
    "hospital_ward/frid.txt"
    ]

delta = 2
result_files = run_delta_conformity(file_list, delta)
# Out:
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 6684.68it/s]

# %%
result_files
# Out:
# ['delta_conformity_hospital_ward/delta2_conf_mond.txt',
#  'delta_conformity_hospital_ward/delta2_conf_tues.txt',
#  'delta_conformity_hospital_ward/delta2_conf_wed.txt',
#  'delta_conformity_hospital_ward/delta2_conf_thur.txt',
#  'delta_conformity_hospital_ward/delta2_conf_frid.txt']

# %%
#selected_day_hos = "hospital_ward//tues.txt"
#delta_result_hos = "delta_conformity_hospital_ward//delta2_conf_tues.txt"
selected_day_hos = file_list[1]
delta_result_hos = result_files[1]

g = read_hospital_file(selected_day_hos)

delta_res, nodes_groupby_cat = read_and_plot_results(
    delta_result_hos, g, delta, 'lab',
    palette='tab10',
    alpha=0.7,
    #xticks = ['5am', '7', '9', '11', '1pm', '3', '5', '7'],
    #savefig=True
)
# Out:
# C:\Users\salva\AppData\Roaming\Python\Python37\site-packages\numpy\core\fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\salva\AppData\Roaming\Python\Python37\site-packages\numpy\core\_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
delta_res['1109'] #delta conformity node 1109
# Out:
# [[32, 0.6],
#  [33, 0.65],
#  [34, 0.7142857142857143],
#  [35, 0.13939393939393938],
#  [36, 0.02153846153846155],
#  [37, 0.08888888888888888],
#  [38, 0.5],
#  [39, 0.5]]

# %%
nodes_groupby_cat[1] # MED
# Out:
# [1157, 1144, 1191, 1148, 1159, 1168, 1260, 1221]
